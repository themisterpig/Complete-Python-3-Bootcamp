# %%
from PIL import Image

# %%
mask_m = Image.open('mask.png')

# %%
mask_m.size
# Out:
# (505, 251)

# %%
under = Image.open('word_matrix.png')

# %%
under = under.resize((505,251))
under
# Out:
# <PIL.Image.Image image mode=RGBA size=505x251 at 0x240404435B0>

# %%
mask_m.putalpha(300)

# %%
under
#under.paste(mask_m,(0,0),mask_m)
# Out:
# <PIL.Image.Image image mode=RGBA size=505x251 at 0x240404435B0>

# %%
under.paste(mask_m,(0,0),mask_m)

# %%
under
# Out:
# <PIL.Image.Image image mode=RGBA size=505x251 at 0x240404435B0>
